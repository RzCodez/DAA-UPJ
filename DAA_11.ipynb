# %% [markdown]
# Nama: Kafka Ramadityo
#
# NIM: 2022071036

# %%
"""
a ------- b
|           |
|           |
c ------- d ---- e

"""

graph = {
    "a" : ["b", "c"],
    "b" : ["a", "d"],
    "c" : ["a", "d"],
    "d" : ["e"],
    "e" : ["d"],
}

print(graph)
# Out:
# {'a': ['b', 'c'], 'b': ['a', 'd'], 'c': ['a', 'd'], 'd': ['e'], 'e': ['d']}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
graph = {
    "t" : ["u", "w"],
    "u" : ["v"],
    "v" : ["x"],
    "w" : ["x", "z"],
    "s" : ["x"],
    "z" : ["w"],
}

print(graph)
# Out:
# {'t': ['u', 'w'], 'u': ['t', 'v'], 'v': ['u', 'x'], 'w': ['x', 'z'], 'x': ['w', 's'], 's': ['x'], 'z': ['w']}

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
graph = {
    "r" : ["o", "i"],
    "o" : ["m", "p"],
    "m" : ["n"],
    "i" : ["r", "p"],
    "p" : ["n", "o"],
    "n" : ["m"],
}

print(graph)
# Out:
# {'r': ['o', 'i'], 'o': ['m', 'p'], 'm': ['n'], 'i': ['r', 'p'], 'p': ['n', 'o'], 'n': ['m']}

# %% [markdown]
# Menampilkan simpul pada graph

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

graph_elements = {
    "a" : ["b", "c"],
    "b" : ["a", "d"],
    "c" : ["a", "d"],
    "d" : ["e"],
    "e" : ["d"],
}

g = Graph(graph_elements)

print(g.getVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

graph_elements = {
    "t" : ["u", "w"],
    "u" : ["v"],
    "v" : ["x"],
    "w" : ["x", "z"],
    "s" : ["x"],
    "z" : ["w"],
}

g = Graph(graph_elements)

print(g.getVertices())
# Out:
# ['t', 'u', 'v', 'w', 's', 'z']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

graph_elements = {
    "r" : ["o", "i"],
    "o" : ["m", "p"],
    "m" : ["n"],
    "i" : ["r", "p"],
    "p" : ["n", "o"],
    "n" : ["m"],
}

g = Graph(graph_elements)

print(g.getVertices())
# Out:
# ['r', 'o', 'm', 'i', 'p', 'n']

# %% [markdown]
# Menampilkan sudut pada graph

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = {
    "a" : ["b", "c"],
    "b" : ["a", "d"],
    "c" : ["a", "d"],
    "d" : ["e"],
    "e" : ["d"],
}

g = Graph(graph_elements)

print(g.edges())
# Out:
# [{'b', 'a'}, {'c', 'a'}, {'b', 'd'}, {'c', 'd'}, {'e', 'd'}]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = {
    "t" : ["u", "w"],
    "u" : ["v"],
    "v" : ["x"],
    "w" : ["x", "z"],
    "s" : ["x"],
    "z" : ["w"],
}

g = Graph(graph_elements)

print(g.edges())
# Out:
# [{'t', 'u'}, {'t', 'w'}, {'v', 'u'}, {'v', 'x'}, {'x', 'w'}, {'z', 'w'}, {'s', 'x'}]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = {
    "r" : ["o", "i"],
    "o" : ["m", "p"],
    "m" : ["n"],
    "i" : ["r", "p"],
    "p" : ["n", "o"],
    "n" : ["m"],
}

g = Graph(graph_elements)

print(g.edges())
# Out:
# [{'r', 'o'}, {'i', 'r'}, {'o', 'm'}, {'o', 'p'}, {'n', 'm'}, {'i', 'p'}, {'n', 'p'}]

# %% [markdown]
# Menambah Vertex / simpul

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

    def addVertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []

graph_elements = {
    "a" : ["b", "c"],
    "b" : ["a", "d"],
    "c" : ["a", "d"],
    "d" : ["e"],
    "e" : ["d"],
}

g = Graph(graph_elements)
g.addVertex("f")

print(g.getVertices())
# Out:
# ['a', 'b', 'c', 'd', 'e', 'f']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

    def addVertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []

graph_elements = {
    "t" : ["u", "w"],
    "u" : ["v"],
    "v" : ["x"],
    "w" : ["x", "z"],
    "s" : ["x"],
    "z" : ["w"],
}

g = Graph(graph_elements)
g.addVertex("r")

print(g.getVertices())
# Out:
# ['t', 'u', 'v', 'w', 's', 'z', 'r']

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def getVertices(self):
        return list(self.gdict.keys())

    def addVertex(self, vrtx):
        if vrtx not in self.gdict:
            self.gdict[vrtx] = []

graph_elements = {
    "r" : ["o", "i"],
    "o" : ["m", "p"],
    "m" : ["n"],
    "i" : ["r", "p"],
    "p" : ["n", "o"],
    "n" : ["m"],
}

g = Graph(graph_elements)
g.addVertex("k")
g.gdict["k"].append("j")


print(g.getVertices())
# Out:
# ['r', 'o', 'm', 'i', 'p', 'n', 'k']

# %% [markdown]
# Menambahkan Edge / Sudut

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def AddEdge(self, edge):
        edge = set(edge)
        (vrtx1, vrtx2) = tuple(edge)
        if vrtx1 in self.gdict:
            self.gdict[vrtx1].append(vrtx2)
        else:
            self.gdict[vrtx1] = [vrtx2]

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = {
    "a" : ["b", "c"],
    "b" : ["a", "d"],
    "c" : ["a", "d"],
    "d" : ["e"],
    "e" : ["d"],
}

g = Graph(graph_elements)
g.AddEdge({"f", "b"})
g.AddEdge({"f", "e"})

print(g.edges())
# Out:
# [{'b', 'a'}, {'c', 'a'}, {'b', 'd'}, {'c', 'd'}, {'e', 'd'}, {'f', 'b'}, {'f', 'e'}]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def AddEdge(self, edge):
        edge = set(edge)
        (vrtx1, vrtx2) = tuple(edge)
        if vrtx1 in self.gdict:
            self.gdict[vrtx1].append(vrtx2)
        else:
            self.gdict[vrtx1] = [vrtx2]

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = {
    "t" : ["u", "w"],
    "u" : ["v"],
    "v" : ["x"],
    "w" : ["x", "z"],
    "s" : ["x"],
    "z" : ["w"],
}

g = Graph(graph_elements)
g.AddEdge({"t", "z"})
g.AddEdge({"v", "s"})

print(g.edges())
# Out:
# [{'t', 'u'}, {'t', 'w'}, {'t', 'z'}, {'v', 'u'}, {'v', 'x'}, {'x', 'w'}, {'z', 'w'}, {'s', 'x'}, {'s', 'v'}]

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
class Graph:
    def __init__(self, gdict=None):
        if gdict is None:
            gdict: {}
        self.gdict = gdict

    def edges(self):
        return self.findedges()

    def AddEdge(self, edge):
        edge = set(edge)
        (vrtx1, vrtx2) = tuple(edge)
        if vrtx1 in self.gdict:
            self.gdict[vrtx1].append(vrtx2)
        else:
            self.gdict[vrtx1] = [vrtx2]

    def findedges(self):
        edgename = []
        for vrtx in self.gdict:
            for nxtvrtx in self.gdict[vrtx]:
                if {nxtvrtx, vrtx} not in edgename:
                    edgename.append({vrtx, nxtvrtx})
        return edgename

graph_elements = {
     "r" : ["o", "i"],
    "o" : ["m", "p"],
    "m" : ["n"],
    "i" : ["r", "p"],
    "p" : ["n", "o"],
    "n" : ["m"],
}

g = Graph(graph_elements)
g.AddEdge({"r", "k"})
g.AddEdge({"m", "j"})

print(g.edges())
# Out:
# [{'r', 'o'}, {'i', 'r'}, {'r', 'k'}, {'o', 'm'}, {'o', 'p'}, {'n', 'm'}, {'i', 'p'}, {'n', 'p'}, {'j', 'm'}]
